# %% [markdown]
# # Marshall JMP's modeling using a recurrent neural network.
#
# This notebook ran on Kaggle with GPU. The dataset used was **tube-guitar-amplifiers-v1** (https://www.kaggle.com/filipechagas/tube-guitar-amplifiers-v1).

# %%
import numpy as np
from typing import *

files = {
    'jmp': '/kaggle/input/tube-guitar-amplifiers-v1/jmp.wav',
    'jmp2': '/kaggle/input/tube-guitar-amplifiers-v1/jmp2.wav',
    'od120': '/kaggle/input/tube-guitar-amplifiers-v1/od120.wav',
    'twin': '/kaggle/input/tube-guitar-amplifiers-v1/twin.wav',
    'clean': '/kaggle/input/tube-guitar-amplifiers-v1/clean.wav'
}

amplifier = 'jmp'

# %% [markdown]
# ## Signal processing functions
#
# The target audio (y dataset) goes through a treble boost for the training of the neural network so that the training fits it better for the amplifier's treble. Therefore, the neural network predictor must be proceeded by an "unboost 'of treble.

# %%
#Credits: https://medium.com/analytics-vidhya/how-to-filter-noise-with-a-low-pass-filter-python-885223e5e9b7

from scipy.signal import butter,filtfilt

def butter_lowpass_filter(data: np.ndarray, cutoff: float, fs: float, order: int) -> np.ndarray:
    nyq = fs/2
    normal_cutoff = cutoff / nyq
    # Get the filter coefficients 
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, data)
    return y

def butter_highpass_filter(data: np.ndarray, cutoff: float, fs: float, order: int) -> np.ndarray:
    nyq = fs/2
    normal_cutoff = cutoff / nyq
    # Get the filter coefficients 
    b, a = butter(order, normal_cutoff, btype='high', analog=False)
    y = filtfilt(b, a, data)
    return y

def treble_boost(data: np.ndarray, freq: float, gain: float, fs: float) -> np.ndarray:
    order = 10
    low = butter_lowpass_filter(data, freq, fs, order)
    high = butter_highpass_filter(data, freq, fs, order)
    return low + high*gain
    
def treble_unboost(data: np.ndarray, freq: float, gain: float, fs: float) -> np.ndarray:
    order = 10
    low = butter_lowpass_filter(data, freq, fs, order)
    high = butter_highpass_filter(data, freq, fs, order)
    return low + high/gain

# %% [markdown]
# ## Dataset preprocessing
#
# The RNN's input is a audio chunck of 1024 normalized samples. Dataset's preprocessing must turn audio to sequences of chuncks and normalize it by dividing samples by $2^{16}$.

# %%
def split_wave(data: np.ndarray, samples_per_slice: int) -> List[np.ndarray]:
    '''
    Split wave data to slices.
    Params:
        data (np.ndarray): NumPy array containing audio signal.
        samples_per_slice (int): Quantity of audio samples in each slice.
    
    Returns (List[np.ndarray]): List of slices.
    '''
    assert len(data.shape) == 1 #data shape must be (length,)

    n_samples = data.shape[0] #Quantity of samples in data
    n_slices = n_samples // samples_per_slice #Quantity of slices 

    l = [] #List where the slices will be inserted
    for i in range(n_slices):
        slc = data[i*samples_per_slice : (i+1)*samples_per_slice] #Slice
        l.append(slc)
    
    return l

# %%
import scipy.io.wavfile as wave

def load_dataset(x_filename: str, y_filename: str, samples_per_input: int, treble_boost_y=False) -> Tuple[np.ndarray, np.ndarray]:
    '''
    Load wave files as a dataset for keras.
    Params:
        x_filename (str): Name of the wave file with input data.
        y_filename (str): Name of the wave file with target data.
        samples_per_slice (int): Quantity of samples in each NN input.
        treble_boost_y (bool): Boost (gain=2) the high frequencies (1KHz-20Khz) of Y audio. 
    '''
    x_data = wave.read(x_filename)[1] #read data from the wav file
    x_data = x_data / (2**16) #normalize data
    
    y_data = wave.read(y_filename)[1] #read data from the wav file
    y_data = y_data / (2**16) #normalize data
    
    if treble_boost_y == True:
        y_data = treble_boost(y_data, 1000, 2, 44100)
    
    y_data = butter_lowpass_filter(y_data, 10000, 44100, 10) #Cut frequencies above 10KHz
    
    # --- Split entire audio to chuncks ---
    x_slices = split_wave(x_data, samples_per_input) 
    y_slices = split_wave(y_data, samples_per_input)
    
    x_dataset = np.vstack(x_slices)
    y_dataset = np.vstack(y_slices)
    
    return (x_dataset, y_dataset)

chunck_len = 1024

x, y = load_dataset(files['clean'], files[amplifier], chunck_len, treble_boost_y=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   if sys.path[0] == '':
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## Model building and training

# %%
#Building model

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def build_model(input_len: int) -> keras.Sequential:
    '''
    Generate the Keras RNN model.
    Params:
        input_len (int) - Length of the input audio chunck.
        
    Returns (keras.Sequential): The keras model.
    '''
    model = keras.Sequential([
        keras.Input(shape=(input_len,)),
        layers.Reshape((input_len,1)),
        layers.LSTM(12, return_sequences=True),
        layers.Dropout(0.3),
        layers.LSTM(12, return_sequences=True),
        layers.Dropout(0.3),
        layers.Flatten(),
        layers.Dense(input_len*20, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(input_len*10, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(input_len, activation='linear'),
    ])

    model.compile(loss='mse', optimizer='rmsprop')

    return model

model = build_model(chunck_len)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 1024, 1)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 1024, 12)          672
# _________________________________________________________________
# dropout (Dropout)            (None, 1024, 12)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1024, 12)          1200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024, 12)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 12288)             0
# _________________________________________________________________
# dense (Dense)                (None, 20480)             251678720
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 20480)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10240)             209725440
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 10240)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              10486784
# =================================================================
# Total params: 471,892,816
# Trainable params: 471,892,816
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Training

es = keras.callbacks.EarlyStopping(patience=10)

hist = model.fit(x, y, batch_size=200, epochs=1000, validation_split=0.25, callbacks=[es])

model.save(f'{amplifier}_lstm_model.h5')
# Out:
# Epoch 1/1000
# 31/31 [==============================] - 15s 299ms/step - loss: 6.8756e-04 - val_loss: 4.5800e-04
# Epoch 2/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 6.2234e-04 - val_loss: 4.6021e-04
# Epoch 3/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 5.9326e-04 - val_loss: 4.6223e-04
# Epoch 4/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 5.8619e-04 - val_loss: 4.6795e-04
# Epoch 5/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 5.4813e-04 - val_loss: 4.6893e-04
# Epoch 6/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 5.4490e-04 - val_loss: 4.6662e-04
# Epoch 7/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 5.1580e-04 - val_loss: 4.6760e-04
# Epoch 8/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 5.2082e-04 - val_loss: 4.5844e-04
# Epoch 9/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 4.9845e-04 - val_loss: 4.6617e-04
# Epoch 10/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 5.0395e-04 - val_loss: 4.5341e-04
# Epoch 11/1000
# 31/31 [==============================] - 8s 268ms/step - loss: 4.8441e-04 - val_loss: 4.6450e-04
# Epoch 12/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 4.6831e-04 - val_loss: 4.4626e-04
# Epoch 13/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 4.4598e-04 - val_loss: 4.4463e-04
# Epoch 14/1000
# 31/31 [==============================] - 8s 271ms/step - loss: 4.4518e-04 - val_loss: 4.5069e-04
# Epoch 15/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 4.2268e-04 - val_loss: 4.4884e-04
# Epoch 16/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 3.9519e-04 - val_loss: 4.3820e-04
# Epoch 17/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 3.8299e-04 - val_loss: 4.6551e-04
# Epoch 18/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 3.7661e-04 - val_loss: 4.1750e-04
# Epoch 19/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 3.7179e-04 - val_loss: 4.2688e-04
# Epoch 20/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 3.4679e-04 - val_loss: 4.1178e-04
# Epoch 21/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 3.2256e-04 - val_loss: 3.9603e-04
# Epoch 22/1000
# 31/31 [==============================] - 8s 271ms/step - loss: 3.1530e-04 - val_loss: 3.9486e-04
# Epoch 23/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 3.1247e-04 - val_loss: 3.8501e-04
# Epoch 24/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 3.0159e-04 - val_loss: 3.8933e-04
# Epoch 25/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 2.8877e-04 - val_loss: 4.0968e-04
# Epoch 26/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 2.7165e-04 - val_loss: 3.7406e-04
# Epoch 27/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 2.7430e-04 - val_loss: 3.8785e-04
# Epoch 28/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 2.6380e-04 - val_loss: 3.8276e-04
# Epoch 29/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 2.5925e-04 - val_loss: 3.6517e-04
# Epoch 30/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 2.4144e-04 - val_loss: 3.6882e-04
# Epoch 31/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 2.3634e-04 - val_loss: 4.0209e-04
# Epoch 32/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 2.3355e-04 - val_loss: 3.7219e-04
# Epoch 33/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 2.2765e-04 - val_loss: 3.6003e-04
# Epoch 34/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 2.2724e-04 - val_loss: 3.4512e-04
# Epoch 35/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 2.1858e-04 - val_loss: 3.4970e-04
# Epoch 36/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 2.0559e-04 - val_loss: 3.4521e-04
# Epoch 37/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 2.0065e-04 - val_loss: 3.6548e-04
# Epoch 38/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.9800e-04 - val_loss: 3.3853e-04
# Epoch 39/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.9080e-04 - val_loss: 3.6356e-04
# Epoch 40/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.8720e-04 - val_loss: 3.4184e-04
# Epoch 41/1000
# 31/31 [==============================] - 8s 273ms/step - loss: 1.8305e-04 - val_loss: 3.4201e-04
# Epoch 42/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.8080e-04 - val_loss: 3.4736e-04
# Epoch 43/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.7879e-04 - val_loss: 3.3990e-04
# Epoch 44/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.7235e-04 - val_loss: 3.3778e-04
# Epoch 45/1000
# 31/31 [==============================] - 8s 271ms/step - loss: 1.6915e-04 - val_loss: 3.3164e-04
# Epoch 46/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.6339e-04 - val_loss: 3.3994e-04
# Epoch 47/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.6412e-04 - val_loss: 3.4731e-04
# Epoch 48/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.6262e-04 - val_loss: 3.2543e-04
# Epoch 49/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.5979e-04 - val_loss: 3.5804e-04
# Epoch 50/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.6734e-04 - val_loss: 3.3148e-04
# Epoch 51/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.4891e-04 - val_loss: 3.2543e-04
# Epoch 52/1000
# 31/31 [==============================] - 8s 272ms/step - loss: 1.4761e-04 - val_loss: 3.2210e-04
# Epoch 53/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.4843e-04 - val_loss: 3.1844e-04
# Epoch 54/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.4533e-04 - val_loss: 3.3723e-04
# Epoch 55/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.4553e-04 - val_loss: 3.2407e-04
# Epoch 56/1000
# 31/31 [==============================] - 8s 271ms/step - loss: 1.3831e-04 - val_loss: 3.1674e-04
# Epoch 57/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.3637e-04 - val_loss: 3.2459e-04
# Epoch 58/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.4079e-04 - val_loss: 3.1599e-04
# Epoch 59/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.3380e-04 - val_loss: 3.1997e-04
# Epoch 60/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.3425e-04 - val_loss: 3.1466e-04
# Epoch 61/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.3189e-04 - val_loss: 3.1019e-04
# Epoch 62/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.3018e-04 - val_loss: 3.0495e-04
# Epoch 63/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.2491e-04 - val_loss: 3.1094e-04
# Epoch 64/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.2619e-04 - val_loss: 3.0698e-04
# Epoch 65/1000
# 31/31 [==============================] - 8s 271ms/step - loss: 1.2512e-04 - val_loss: 3.0591e-04
# Epoch 66/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.2281e-04 - val_loss: 3.0023e-04
# Epoch 67/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.2041e-04 - val_loss: 2.9953e-04
# Epoch 68/1000
# 31/31 [==============================] - 8s 271ms/step - loss: 1.1639e-04 - val_loss: 3.1006e-04
# Epoch 69/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.1839e-04 - val_loss: 3.0478e-04
# Epoch 70/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.1815e-04 - val_loss: 3.0018e-04
# Epoch 71/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.1731e-04 - val_loss: 3.1079e-04
# Epoch 72/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.1224e-04 - val_loss: 2.9451e-04
# Epoch 73/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.1421e-04 - val_loss: 3.0506e-04
# Epoch 74/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.1562e-04 - val_loss: 2.9681e-04
# Epoch 75/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.1366e-04 - val_loss: 3.0373e-04
# Epoch 76/1000
# 31/31 [==============================] - 8s 272ms/step - loss: 1.1264e-04 - val_loss: 2.9581e-04
# Epoch 77/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.0788e-04 - val_loss: 2.9313e-04
# Epoch 78/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.0757e-04 - val_loss: 2.9253e-04
# Epoch 79/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.1063e-04 - val_loss: 2.8962e-04
# Epoch 80/1000
# 31/31 [==============================] - 8s 271ms/step - loss: 1.0941e-04 - val_loss: 2.9280e-04
# Epoch 81/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.0902e-04 - val_loss: 2.9365e-04
# Epoch 82/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.0652e-04 - val_loss: 2.9763e-04
# Epoch 83/1000
# 31/31 [==============================] - 8s 272ms/step - loss: 1.0376e-04 - val_loss: 2.9187e-04
# Epoch 84/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.0580e-04 - val_loss: 2.9065e-04
# Epoch 85/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.0564e-04 - val_loss: 3.0471e-04
# Epoch 86/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.0647e-04 - val_loss: 2.8505e-04
# Epoch 87/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.0023e-04 - val_loss: 2.9051e-04
# Epoch 88/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.0054e-04 - val_loss: 2.8964e-04
# Epoch 89/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 9.9744e-05 - val_loss: 2.9132e-04
# Epoch 90/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.0121e-04 - val_loss: 2.8358e-04
# Epoch 91/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 9.8295e-05 - val_loss: 2.9258e-04
# Epoch 92/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 9.8715e-05 - val_loss: 2.8393e-04
# Epoch 93/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 1.0050e-04 - val_loss: 2.8973e-04
# Epoch 94/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 1.0020e-04 - val_loss: 2.8574e-04
# Epoch 95/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 9.4655e-05 - val_loss: 2.8150e-04
# Epoch 96/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 9.7221e-05 - val_loss: 2.8265e-04
# Epoch 97/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 9.7569e-05 - val_loss: 2.8259e-04
# Epoch 98/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 9.6064e-05 - val_loss: 2.9809e-04
# Epoch 99/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 9.7419e-05 - val_loss: 2.7863e-04
# Epoch 100/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 9.5500e-05 - val_loss: 2.8117e-04
# Epoch 101/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 9.3368e-05 - val_loss: 2.8224e-04
# Epoch 102/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 9.0913e-05 - val_loss: 2.8426e-04
# Epoch 103/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 9.2838e-05 - val_loss: 2.7644e-04
# Epoch 104/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 8.8766e-05 - val_loss: 2.7616e-04
# Epoch 105/1000
# 31/31 [==============================] - 8s 271ms/step - loss: 9.0425e-05 - val_loss: 2.7930e-04
# Epoch 106/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 9.0750e-05 - val_loss: 2.8404e-04
# Epoch 107/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 9.0498e-05 - val_loss: 2.8256e-04
# Epoch 108/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 8.8495e-05 - val_loss: 2.8128e-04
# Epoch 109/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 8.9735e-05 - val_loss: 2.7720e-04
# Epoch 110/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 8.8185e-05 - val_loss: 2.7827e-04
# Epoch 111/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 8.9451e-05 - val_loss: 2.7937e-04
# Epoch 112/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 9.1361e-05 - val_loss: 2.8222e-04
# Epoch 113/1000
# 31/31 [==============================] - 8s 269ms/step - loss: 8.9098e-05 - val_loss: 2.7663e-04
# Epoch 114/1000
# 31/31 [==============================] - 8s 270ms/step - loss: 8.8556e-05 - val_loss: 2.7713e-04

# %% [markdown]
# ## Final results
#
# The final results consist of a graph showing the training history and an audio processed by the model.

# %%
#Plotting training history

import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Testing the model and saving result to a wav file

x_test = x[:x.shape[0]//2]
y_test = model.predict(x_test)

y_test = y_test.reshape((1,y_test.shape[0]*y_test.shape[1]))[0] #Join chuncks to a single audio signal
y_test = treble_unboost(y_test, 1000, 2, 44100) #Unboost treble (1KHz-20KHz)
y_test = butter_lowpass_filter(y_test, 10000, 44100, 10) #Cut frequencies above 10KHz

wave.write(f'{amplifier}_lstm_predict.wav', 44100, y_test)
